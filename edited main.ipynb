# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

Regressors = {}
Hyperparams = {}

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### General

# %%
data = pd.read_csv('raw_complete.csv')
data.drop(data.columns[[0,1]], axis=1, inplace=True)
data.head(2)

#Target Feature
target = ["Rating"]

#Clean the budget
data['Budget'] = data['Budget'].str.replace(',', '', regex=False).str.extract(r'\$(\d+)')
budget = pd.to_numeric(data['Budget'], errors='coerce')
data['Budget'] = budget

#Make features everything but the target
features = list(data.columns)
features.remove(target[0])
feature_dict = {}

print(f'Dataset is now {len(data.columns)}-dimensional')
data.tail(2)
# Out:
# Dataset is now 12-dimensional
#                                          Title  Year  \
# 3242  14. Jamie Foxx: What Had Happened Was...  2024
# 3243            15. Jack in Time for Christmas  2024
#
#                                                    Plot  Rating  Budget  \
# 3242  A stand-up special with Jamie Foxx performing ...     5.8     NaN
# 3243  Jack Whitehall races against time to get from ...     4.6     NaN
#
#                                                    Cast MPA Rating  \
# 3242  Jamie Foxx,Craig Brockman,Nisan Stewart,Bennet...      TV-MA
# 3243  Jack Whitehall,Dave Bautista,Michael Bublé,Dai...      TV-MA
#
#             Directors                           Distributors  \
# 3242  Hamish Hamilton                        Netflix,Netflix
# 3243      Phil Ashton  Amazon Prime Video,Amazon Prime Video
#
#                                               Producers               Genre  \
# 3242  Done and Dusted Productions,Foxxhole Productio...  Documentary,Comedy
# 3243                      Jackpot Productions,Workerbee              Comedy
#
#       Runtime in Minutes
# 3242                  68
# 3243                  66

# %% [markdown]
# ### MPA Ratings

# %%
Ratings = {
    'G': 1,
    'PG': 2,
    'PG-13': 3,
    'R': 4,
    'NC-17':5}

data['MPA Rating'] = data['MPA Rating'].map(Ratings)
data['MPA Rating'] = data['MPA Rating'].fillna(6)

print(f'Dataset is now {len(data.columns)}-dimensional')
data.head(2)
# Out:
# Dataset is now 12-dimensional
#          Title  Year                                               Plot  \
# 0  1. Whiplash  2014  A promising young drummer enrolls at a cut-thr...
# 1   2. RoboCop  2014  In 2028 Detroit, when Alex Murphy, a loving hu...
#
#    Rating       Budget                                               Cast  \
# 0     8.5    3300000.0  Miles Teller,J.K. Simmons,Paul Reiser,Melissa ...
# 1     6.1  100000000.0  Joel Kinnaman,Gary Oldman,Michael Keaton,Abbie...
#
#    MPA Rating        Directors  \
# 0         6.0  Damien Chazelle
# 1         6.0     José Padilha
#
#                                         Distributors  \
# 0  Sony Pictures Classics,Sony Pictures Worldwide...
# 1  Columbia Pictures,ACME,ACME,ACME,B&H Film Dist...
#
#                                            Producers  \
# 0  Bold Films,Blumhouse Productions,Right of Way ...
# 1  Metro-Goldwyn-Mayer (MGM),Columbia Pictures,St...
#
#                           Genre  Runtime in Minutes
# 0                   Drama,Music                 106
# 1  Action,Crime,Sci-Fi,Thriller                 117

# %%
# Calculate quartiles and IQR
Q1 = data['Budget'].quantile(0.25)
Q3 = data['Budget'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter outliers
outliers_iqr = data[(data['Budget'] < lower_bound) | (data['Budget'] > upper_bound)]
outliers_iqr.sort_values(by=['Budget']).tail(10)
# Out:
#                                                Title  Year  \
# 2119                 2. Zack Snyder's Justice League  2021
# 1164      3. Star Wars: Episode VIII - The Last Jedi  2017
# 1260                       1. Avengers: Infinity War  2018
# 2768                                       2. Fast X  2023
# 2643                     2. Avatar: The Way of Water  2022
# 573                                 Lucasfilm,Bad Robot
#
#                                          Genre  Runtime in Minutes
# 2119           Action,Adventure,Fantasy,Sci-Fi                 242
# 1164           Action,Adventure,Fantasy,Sci-Fi                 152
# 1260                   Action,Adventure,Sci-Fi                 149
# 2768   Action,Adventure,Crime,Mystery,Thriller                 141
# 2643           Action,Adventure,Fantasy,Sci-Fi                 192
# 2770  Adventure,Family,Fantasy,Musical,Romance                 135
# 1557                   Action,Adventure,Sci-Fi                 181
# 2772                   Action,Adventure,Sci-Fi                 154
# 2472           Action,Adventure,Fantasy,Sci-Fi                 126
# 573                    Action,Adventure,Sci-Fi                 138

# %%
# I checked, they should be the same.
data.loc[2770, 'Budget'] = 40_000_000
data.loc[573, 'Budget'] = 245_000_000
data.loc[669, 'Budget'] = 30_000_000
# Out:
# ('4. The Little Mermaid',
#  '3. Star Wars: Episode VII - The Force Awakens',
#  "24. Pee-wee's Big Holiday")

# %%
# Calculate quartiles and IQR
Q1 = data['Runtime in Minutes'].quantile(0.25)
Q3 = data['Runtime in Minutes'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter outliers
outliers_iqr = data[(data['Runtime in Minutes'] < lower_bound) | (data['Runtime in Minutes'] > upper_bound)]
outliers_iqr.sort_values(by=['Runtime in Minutes']).tail(1)

# %%
# Calculate dynamic bin edges
min_val = data['Rating'].min()
max_val = data['Rating'].max()
q1 = data['Rating'].quantile(0.25)
q2 = data['Rating'].quantile(0.50)
q3 = data['Rating'].quantile(0.75)

# Create bins with these values
bins = [min_val, q2, max_val]

# Use pd.cut to assign categorical labels based on the computed bins
data['Rating'] = pd.cut(
    data['Rating'],
    bins=bins,
    labels=['bad','good'],
    include_lowest=True
)

# %% [markdown]
# ## Split

# %%
# Split data -> nontest & test
x_nontest, x_test, y_nontest, y_test = train_test_split(data[features], data[target], test_size=0.2, random_state=1337)

# 60% of the entire dataset = train
# 20% of the entire dataset = val
x_train, x_val, y_train, y_val = train_test_split(x_nontest, y_nontest, test_size=0.25, random_state=1337)

print(f'Val Size: {len(x_val)}')
print(f'Train size: {len(x_train)}')
print(f'Test size: {len(x_test)}')
# Out:
# Val Size: 649
# Train size: 1946
# Test size: 649

# %% [markdown]
# ## Vectorization

# %%
# fit using Train Set
vectorizer = TfidfVectorizer(token_pattern =r'[a-zA-Z]+', min_df=0.001, stop_words=list(sklearn.feature_extraction.text.ENGLISH_STOP_WORDS))
vectorizer.fit(x_train['Plot'])
tokens = vectorizer.get_feature_names_out()
feature_dict['tokens'] = list(tokens)

# Train Set
trainIDF = vectorizer.transform(x_train['Plot'])
x_train_wordvec = pd.DataFrame(trainIDF.toarray(), columns=tokens, index=x_train.index)
x_train_temp = pd.concat([x_train, x_train_wordvec], axis=1)
x_train.drop(columns=['Plot'], inplace=True)

# Test Set
testIDF = vectorizer.transform(x_test['Plot'])
x_test_wordvec = pd.DataFrame(testIDF.toarray(), columns=tokens, index=x_test.index)
x_test_temp = pd.concat([x_test, x_test_wordvec], axis=1)
x_test.drop(columns=['Plot'], inplace=True)

# Validation Set
valIDF = vectorizer.transform(x_val['Plot'])
x_val_wordvec = pd.DataFrame(valIDF.toarray(), columns=tokens, index=x_val.index)
x_val_temp = pd.concat([x_val, x_val_wordvec], axis=1)
x_val.drop(columns=['Plot'], inplace=True)

print(f'Dataset is now {len(x_val_temp.columns)}-dimensional')
x_val.head(2)
# Out:
# Dataset is now 12207-dimensional
#                Title  Year  Budget  \
# 2313   22. The Manor  2021     NaN
# 1309  25. The Toybox  2018     NaN
#
#                                                    Cast  MPA Rating  \
# 2313  Barbara Hershey,Bruce Davison,Nicholas Alexand...         6.0
# 1309  Denise Richards,Mischa Barton,Jeff Denton,Bria...         6.0
#
#            Directors                                       Distributors  \
# 2313  Axelle Carolyn                                 Amazon Prime Video
# 1309       Tom Nagel  High Fliers Films,Skyline Entertainment,Sunfil...
#
#                                               Producers           Genre  \
# 2313  Amazon Studios,Blumhouse Television,Storm King...  Horror,Mystery
# 1309  Steel House Productions,Millman Productions,Sk...          Horror
#
#       Runtime in Minutes
# 2313                  81
# 1309                  95

# %%
to_be_encoded = ['Cast', 'Directors', 'Distributors', 'Producers', 'Genre']

for feat in to_be_encoded:
    vectorizer = CountVectorizer(token_pattern =r'(.+?),', max_features = 100)
    vectorizer.fit(x_train[feat])
    tokens = vectorizer.get_feature_names_out()
    feature_dict[feat] = list(tokens)

    #Train Set
    trainIDF = vectorizer.transform(x_train[feat])
    x_train_wordvec = pd.DataFrame(trainIDF.toarray(), columns=tokens, index=x_train.index)
    x_train = pd.concat([x_train, x_train_wordvec], axis=1)

    #Test Set
    testIDF = vectorizer.transform(x_test[feat])
    x_test_wordvec = pd.DataFrame(testIDF.toarray(), columns=tokens, index=x_test.index)
    x_test = pd.concat([x_test, x_test_wordvec], axis=1)

    #Validation Set
    valIDF = vectorizer.transform(x_val[feat])
    x_val_wordvec = pd.DataFrame(valIDF.toarray(), columns=tokens, index=x_test.index)
    x_val = pd.concat([x_val, x_val_wordvec], axis=1)

x_val.drop(columns=to_be_encoded, inplace=True)
x_nontest.drop(columns=to_be_encoded, inplace=True)
x_test.drop(columns=to_be_encoded, inplace=True)

print(f'Dataset is now {len(x_test.columns)}-dimensional')
x_test.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 20
#      17 x_test = pd.concat([x_test, x_test_wordvec], axis=1)
#      19 #Validation Set
# ---> 20 valIDF = vectorizer.transform(x_val[feat])
#      21 x_val_wordvec = pd.DataFrame(valIDF.toarray(), columns=tokens, index=x_test.index)
#      22 x_val = pd.concat([x_val, x_val_wordvec], axis=1)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:1421, in CountVectorizer.transform(self, raw_documents)
#    1418 self._check_vocabulary()
#    1420 # use the same matrix-building strategy as fit_transform
# -> 1421 _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1422 if self.binary:
#    1423     X.data.fill(1)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:1263, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1261 for doc in raw_documents:
#    1262     feature_counter = {}
# -> 1263     for feature in analyze(doc):
#    1264         try:
#    1265             feature_idx = vocabulary[feature]
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:99, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      77 """Chain together an optional series of text processing steps to go from
#      78 a single document to ngrams, with or without tokenizing or preprocessing.
#      79
#    (...)
#      95     A sequence of tokens, possibly with pairs, triples, etc.
#      96 """
#      98 if decoder is not None:
# ---> 99     doc = decoder(doc)
#     100 if analyzer is not None:
#     101     doc = analyzer(doc)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:232, in _VectorizerMixin.decode(self, doc)
#     229     doc = doc.decode(self.encoding, self.decode_error)
#     231 if doc is np.nan:
# --> 232     raise ValueError(
#     233         "np.nan is an invalid document, expected byte or unicode string."
#     234     )
#     236 return doc
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %% [markdown]
# ## PCA
