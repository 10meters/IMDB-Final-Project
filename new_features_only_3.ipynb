# %% [markdown]
# 1. Data Scraping
#
# We collect the top *n* movies sorted by year with the following criteria:
# - Have atleast 1000 reviews
# - Is a Movie (Not a series)
# - Is in English

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from imdb import Cinemagoer
import calendar
import re
import IPython

import socket
socket.setdefaulttimeout(120)

# %%
base_url = 'https://www.imdb.com/search/title/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

cg = Cinemagoer()

# Initialize lists and session
titles = []
plots = []
ratings = []
budgets = []
years = []
session = requests.Session()  # Crucial for maintaining cookies

# New Lists
cast = []
mpa_ratings = []
directors = []
distributors = []
producers = []
genres = []
runtime = []

# Loop through each year and month from 2019 to 2024
for year in range(2018, 2019+1):
    for month in range(1, 13):
        IPython.display.clear_output()
        print(f"{year}-{month:02d}")

        # Calculate start and end dates for the month
        # Generated by DeepSeek
        last_day = calendar.monthrange(int(year), int(month))[1]
        start_date = f"{year}-{month:02d}-01"
        end_date = f"{year}-{month:02d}-{last_day:02d}"

        # Set parameters with the current month's date range
        # Generated by DeepSeek
        params = {
            'title_type': 'feature',
            'num_votes': 1000,
            'primary_language': 'en',
            'sort': 'year,asc',
            'release_date': f"{start_date},{end_date}"
        }

        # Make request for the current month
        # Generated by ChatGPT
        response = session.get(base_url, params=params, headers=headers, timeout=70)
        if response.status_code != 200:
            print(f"Failed to retrieve data for {year}-{month:02d}, status code: {response.status_code}")
            continue

        soup = BeautifulSoup(response.content, 'html.parser')
        movies = soup.find_all('div', class_='ipc-metadata-list-summary-item__tc')

        for movie in movies:
            RETRY_ATTEMPTS = 3
            for attempt in range(1, RETRY_ATTEMPTS + 1):
                try:
                    # Title
                    title_tag = movie.find('h3', class_='ipc-title__text')
                    title = title_tag.text.strip() if title_tag else 'N/A'
                    id = re.search(r"/title/tt([0-9]+)/",title_tag.parent.get("href")).group(1)
                    
                    # Actors
                    movie = cg.get_movie(id)
                    actors = movie.get('cast')
                    actors = [str(actor) for actor in actors]
                    actors = ",".join(actors)

                    #Rating
                    rating = movie['rating']
                    
                    #Budget
                    bo = movie.get('box office')
                    budget = bo.get('Budget') if bo else 'N/A'
                    
                    #Plot
                    plot = movie.get('plot')
                    plot = " ".join(plot) if plot else 'N/A'
                    
                    # MPA Ratings
                    certs = movie.get('certificates')
                    certs = ",".join(certs) + " "
                    certs = re.search(r"United States:(.*?)[\b,\: ]",certs)
                    certs = certs.group(1) if certs else 'N/A'

                    # Directors
                    director = movie.get('director')
                    director = [str(direct) for direct in director]
                    director = ",".join(director)

                    # Producers
                    prod_list = movie.get('production companies')
                    prod_list = [str(prod) for prod in prod_list]
                    prod_list = ",".join(prod_list)
                    

                    # Distributors
                    dist_list = movie.get('distributors')
                    dist_list = [str(dist) for dist in dist_list]
                    dist_list = ",".join(dist_list)
                    
                    # Genre
                    genre = movie.get('genres')
                    genre = [str(gen) for gen in genre]
                    genre = ",".join(genre)

                    # Runtime
                    run = movie.get('runtimes')
                    run = ",".join(run)

                    #appends
                    ratings.append(rating)
                    titles.append(title)
                    genres.append(genre)
                    distributors.append(dist_list)
                    directors.append(director)
                    mpa_ratings.append(certs)
                    plots.append(plot)
                    budgets.append(budget)
                    cast.append(actors)
                    runtime.append(run)
                    years.append(year)
                    producers.append(prod_list)
                    break
                except:
                    print(id)
                    sleep(1)
# Out:
# 2019-12
# 4130484
# 4130484
# 4130484

# %%
len(mpa_ratings)
# Out:
# 591

# %%
# Create DataFrame
df = pd.DataFrame({
    'Title': titles,
    'Year' : years,
    'Plot': plots,
    'Rating': ratings,
    'Budget': budgets,
    'Cast': cast,
    'MPA Rating': mpa_ratings,
    'Directors': directors,
    'Distributors': distributors,
    'Producers': producers,
    'Genre': genres,
    'Runtime in Minutes': runtime
})

print(f"Total movies scraped: {len(df)}")
df
# Out:
# Total movies scraped: 591
#                                       Title  Year  \
# 0                         1. Den of Thieves  2018
# 1                             2. Hereditary  2018
# 2                          3. Black Panther  2018
# 3                              4. 12 Strong  2018
# 4                           5. Eighth Grade  2018
# ..                                      ...   ...
# 586                              21. Hammer  2019
# 587  22. The Murder of Nicole Brown Simpson  2019
# 588  23. A Christmas Prince: The Royal Baby  2019
# 589                  24. The Madness Within  2019
# 590                          25. Apparition  2019
#
#                                                   Plot  Rating  \
# 0    An elite unit of the LA County Sheriff's Dept....     7.0
# 1    A grieving family is haunted by tragic and dis...     7.3
# 2    T'Challa, heir to the hidden but advanced king...     7.3
# 3    12 Strong tells the story of the first Special...     6.5
# 4    An introverted teenage girl tries to survive t...     7.3
# ..                                                 ...     ...
# 586  A father faces a personal crisis when he disco...     5.7
# 587  Inspired by true events, the film follows OJ S...     2.6
# 588  It's Christmastime in Aldovia, and a royal bab...     5.4
# 589  Russ Washington is a successful businessman on...     4.6
# 590  A group of young people, guided by an app whic...     3.2
#
#                        Budget  \
# 0     $30,000,000 (estimated)
# 1     $10,000,000 (estimated)
# 2    $200,000,000 (estimated)
# 3     $35,000,000 (estimated)
# 4      $2,000,000 (estimated)
# ..                        ...
# 586                       N/A
# 587                       N/A
# 588                       N/A
# 589    $1,000,000 (estimated)
# 590    $1,000,000 (estimated)
#
#                                                   Cast MPA Rating  \
# 0    Gerard Butler,Pablo Schreiber,O'Shea Jackson J...      TV-14
# 1    Alex Wolff,Gabriel Byrne,Toni Collette,Milly S...      TV-14
# 2    Chadwick Boseman,Michael B. Jordan,Lupita Nyon...      PG-13
# 3    Chris Hemsworth,Michael Shannon,Michael Peña,N...          R
# 4    Elsie Fisher,Josh Hamilton,Emily Robinson,Jake...      TV-PG
# ..                                                 ...        ...
# 586  Will Patton,Mark O'Brien,Ben Cotton,Vickie Pap...        N/A
# 587  Mena Suvari,Nick Stahl,Taryn Manning,Agnes Bru...          R
# 588  Rose McIver,Ben Lamb,Alice Krige,Honor Kneafse...      TV-PG
# 589  Hunter G. Williams,Edin Gali,Tessa Farrell,Lil...          R
# 590  Kevin Pollak,Mena Suvari,Annalisa Cochrane,Mat...        N/A
#
#               Directors                                       Distributors  \
# 0    Christian Gudegast  STX Entertainment,Ascot Elite Entertainment Gr...
# 1             Ari Aster  A24,BestFilm.eu,Blitz,DeAPlaneta,Diamond Films...
# 2          Ryan Coogler  Walt Disney Studios Motion Pictures,Walt Disne...
# 3       Nicolai Fuglsig  01 Distribution,ACME,ACME,ACME,Aurum Films,Bel...
# 4            Bo Burnham  A24,Sony Pictures Worldwide Acquisitions (SPWA...
# ..                  ...                                                ...
# 586   Christian Sparkes  Vertical Entertainment,A71 Entertainment,Eagle...
# 587     Daniel Farrands  Showtime Networks,GEM Entertainment,Cinemundo,...
# 588        John Schultz                            Netflix,Netflix,Netflix
# 589  Hunter G. Williams          Midnight Releasing,Uncork'd Entertainment
# 590        Waymon Boone  Film & TV House,GEM Entertainment,Digi-Optic F...
#
#                                              Producers  \
# 0    STX Films,Diamond Film Productions,Tucker Tool...
# 1    PalmStar Media,Finch Entertainment,Windy Hill ...
# 2                                       Marvel Studios
# 3    Alcon Entertainment,Black Label Media,Jerry Br...
# 4                                        A24,IAC Films
# ..                                                 ...
# 586  Sara Fost Pictures,Away Films,JoBro Production...
# 587  Skyline Entertainment,Bundy Brown Island,1428 ...
# 588  Netflix,Motion Picture Corporation of America ...
# 589                         Busted Knuckle Productions
# 590                                     Make The Movie
#
#                              Genre Runtime in Minutes
# 0      Action,Crime,Drama,Thriller                140
# 1    Drama,Horror,Mystery,Thriller                127
# 2          Action,Adventure,Sci-Fi                134
# 3         Action,Drama,History,War                130
# 4                     Comedy,Drama                 93
# ..                             ...                ...
# 586           Crime,Drama,Thriller                 82
# 587  Crime,Horror,Mystery,Thriller                 82
# 588                 Family,Romance                 84
# 589                       Thriller                 97
# 590                         Horror                 83
#
# [591 rows x 12 columns]

# %%
df.to_csv("raw3.csv")
print("DONE")
# Out:
# DONE
